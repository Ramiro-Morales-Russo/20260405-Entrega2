# %% [markdown]
# Introducción:

# %%
# Se importará sys y se definirá la como recuperar los archivos .py desde src:
import sys
sys.path.append('../src')

# Se utilizarán comandos de IPrython para recargar las librerías precio a cada ejecución:
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Ejercicio 7:

# %%
import Ejercicio7

# %%
input_participantes = input('Ingrese los participantes (separados por coma):')
input_participantes = input_participantes.split(",")
if(Ejercicio7.validar_participantes(input_participantes)):
    print(Ejercicio7.asignar_amigo_invisible(input_participantes))
else:
    print('El input fue ingresado de forma incorrecta')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 4
#       2 input_participantes = input_participantes.split(",")
#       3 if(Ejercicio7.validar_participantes(input_participantes)):
# ----> 4     print(Ejercicio7.asignar_amigo_invisible(input_participantes))
#       5 else:
#       6     print('El input fue ingresado de forma incorrecta')
#
# File <string>:5, in asignar_amigo_invisible(participantes)
#
# File <string>:5, in asignar_amigo(participante, posibles_asignaciones)
#
# NameError: name 'asignar_amigo' is not defined
