# %% [markdown]
# Introducción:

# %%
# Se importará sys y se definirá la como recuperar los archivos .py desde src:
import sys
sys.path.append('../src')

# Se utilizarán comandos de IPrython para recargar las librerías precio a cada ejecución:
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Ejercicio 8:

# %%
# Implemente el cifrado César, que consiste en desplazar cada letra del alfabeto
# una cantidad fija de posiciones. El programa debe:

# 1- Solicitar un mensaje al usuario.
# 2- Solicitar un valor de desplazamiento (número entero).
# 3- Mostrar el mensaje cifrado.
# 4- Mostrar el mensaje descifrado a partir del cifrado (para verificar que funciona).

import Ejercicio8

# %%
mensaje = input('Ingrese un mensaje: ')
desplazamiento = int(input("Ingrese un valor de desplazamiento: "))
mensaje_cifrado = Ejercicio8.cifrar_mensaje(mensaje, desplazamiento)
print(f'Mensaje cifrado: {mensaje_cifrado}')
mensaje_descifrado = Ejercicio8.descifrar_mensaje(mensaje_cifrado,desplazamiento)
print(f"Mensaje descifrado: {mensaje_descifrado}")
# Out:
# Mensaje cifrado:  Krod Pxqgr!
# Mensaje descifrado:  Hola Mundo!
