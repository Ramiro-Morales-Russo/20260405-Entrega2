# %% [markdown]
# Introducción:

# %%
# Se importará sys y se definirá la como recuperar los archivos .py desde src:
import sys
sys.path.append('../src')

# Se utilizarán comandos de IPrython para recargar las librerías precio a cada ejecución:
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Ejercicio 2:

# %%
playlist = [
    {"title": "Bohemian Rhapsody", "duration": "5:55"},
    {"title": "Hotel California", "duration": "6:30"},
    {"title": "Stairway to Heaven", "duration": "8:02"},
    {"title": "Imagine", "duration": "3:07"},
    {"title": "Smells Like Teen Spirit", "duration": "5:01"},
    {"title": "Billie Jean", "duration": "4:54"},
    {"title": "Hey Jude", "duration": "7:11"},
    {"title": "Like a Rolling Stone", "duration": "6:13"},
]

import Ejercicio2

# %%
# Duración Total de la Playlist:
duraciones = Ejercicio2.extraer_duraciones(playlist)
print(duraciones)  # ['5:55', '6:30', '8:02', '3:07', '5:01', '4:54', '7:11', '6:13']
duraciones_valor = Ejercicio2.transformar_a_valor(duraciones)
print(sum(duraciones_valor))
print(Ejercicio2.duracion_total(duraciones_valor))
# Out:
# ['5:55', '6:30', '8:02', '3:07', '5:01', '4:54', '7:11', '6:13']
# 2813
# 46m 53s
# None

# %%
# Canción más larga:
cancion_max = playlist[Ejercicio2.max_duracion_posicion(duraciones_valor)].get("title")
duracion_max = playlist[Ejercicio2.max_duracion_posicion(duraciones_valor)].get("duration")
print(f"La canción más larga es: {cancion_max} con una duración de: {duracion_max}")
# Out:
# La canción más larga es: Stairway to Heaven con una duración de: 8:02

# %%
# Canción más corta:
cancion_min = playlist[Ejercicio2.min_duracion_posicion(duraciones_valor)].get("title")
duracion_min = playlist[Ejercicio2.min_duracion_posicion(duraciones_valor)].get("duration")
print(f"La canción más corta es: {cancion_min} con una duración de: {duracion_min}")
# Out:
# La canción más corta es: Imagine con una duración de: 3:07
