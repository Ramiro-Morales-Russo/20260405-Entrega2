# %% [markdown]
# Introducción:

# %%
# Se importará sys y se definirá la como recuperar los archivos .py desde src:
import sys
sys.path.append('../src')

# Se utilizarán comandos de IPrython para recargar las librerías precio a cada ejecución:
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Ejercicio 6:

# %%
# Dadas las siguientes publicaciones de una red social, extraiga todos los
# hashtags (palabras que comienzan con #), cuente la frecuencia de cada uno, y
# muestre los hashtags trending (los que aparecen más de una vez).

posts = [
    "Arrancando el lunes con energía #Motivación #NuevaSemana",
    "Terminé mi primer proyecto en Python #Python #Programación #OrgullosoDeMi",
    "No puedo creer el final de la serie #SinSpoilers #SerieAdicta",
    "Nuevo video en el canal sobre #InteligenciaArtificial y #Python",
    "Entrenamiento de hoy completado #Fitness #Motivación #NoPainNoGain",
    "Leyendo sobre #InteligenciaArtificial y el futuro del trabajo #Tecnología",
    "Arranqué a estudiar #Programación por mi cuenta #Python #Autodidacta",
    "Finde de lluvia, maratón de series #SerieAdicta #Relax",
    "Workshop de #InteligenciaArtificial en la universidad #Tecnología #Programación",
]


import Ejercicio6
from collections import Counter

# %%
# Extraer todos los Hashtags:
palabras = Ejercicio6.extraer_hashtags(posts)
print(palabras)
# Out:
# ['#Motivación', '#NuevaSemana', '#Python', '#Programación', '#OrgullosoDeMi', '#SinSpoilers', '#SerieAdicta', '#InteligenciaArtificial', '#Python', '#Fitness', '#Motivación', '#NoPainNoGain', '#InteligenciaArtificial', '#Tecnología', '#Programación', '#Python', '#Autodidacta', '#SerieAdicta', '#Relax', '#InteligenciaArtificial', '#Tecnología', '#Programación']

# %%
trendings = Counter(palabras).most_common()
print('Hashtags tending:')
for hashtag,cantidad in trendings:
    if(cantidad>1):
        print(f'{hashtag}: {cantidad}')
# Out:
# Hashtags tending:
# #Python: 3
# #Programación: 3
# #InteligenciaArtificial: 3
# #Motivación: 2
# #SerieAdicta: 2
# #Tecnología: 2

# %%
# Total Hashtag únicos:
print(f"Total de hashtags únicos: {Ejercicio6.contar_unicos(palabras)}")
# Out:
# Total de hashtags únicos: 13
