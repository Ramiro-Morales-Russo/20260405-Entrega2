# %% [markdown]
# Introducción:

# %%
# Se importará sys y se definirá la como recuperar los archivos .py desde src:
import sys
sys.path.append('../src')

# Se utilizarán comandos de IPrython para recargar las librerías precio a cada ejecución:
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Ejercicio 5:

# %%
# Calcule el costo de envío de un paquete según su peso (en kg) y la zona de
# destino. El usuario debe ingresar ambos valores.

# Si la zona no es válida, debe indicar el error.

import Ejercicio5

# %%
paquete = float(input("Ingrese el peso del paquete: "))
zona = input("Ingrese la zona de destino (local/regional/nacional): ")
costo = Ejercicio5.calcular_envio(paquete,zona)
if(costo == -1):
    print("Zona no válida. Las zonas disponibles son: local, regional, nacional.")
else:
    print(f'El costo total es de: {costo}')
# Out:
# El costo total es de: 2500
